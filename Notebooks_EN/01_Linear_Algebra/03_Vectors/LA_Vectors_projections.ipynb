# %% [markdown]
# <a href="https://colab.research.google.com/github/najaf778/Math-2024-25-Winter/blob/main/Notebooks_EN/01_Linear_Algebra/03_Vectors/LA_Vectors_projections.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Vectors - Projections and Divisions
#
#
# ## Projecting a Vector onto Another Vector
#
# Projecting vector $\mathbf{a}$ onto axis $\mathbf{b}$ involves finding the component of vector $\mathbf{a}$ along the direction of $\mathbf{b}$.
#
# Projection of $\mathbf{a}$ onto $\mathbf{b}$:
#
# $$
# \text{Proj}_{\mathbf{b}} \mathbf{a} = \frac{\mathbf{a} \cdot \mathbf{b}}{|\mathbf{b}|^2} \mathbf{b}
# $$
#
#
# ## Projecting a Vector onto Axes
#
# Projecting vector $\mathbf{a}$ onto an axis involves finding the component of vector $\mathbf{a}$ along that axis.
#
# Projection of $\mathbf{a}$ onto the $OX$ axis:
#
# $$
# \text{Proj}_{OX} \mathbf{a} = \frac{\mathbf{a} \cdot \mathbf{i}}{|\mathbf{i}|^2} \mathbf{i} = \frac{\mathbf{a} \cdot \mathbf{i}}{1} \mathbf{i} = (\mathbf{a} \cdot \mathbf{i}) \mathbf{i}
# $$
#
# Projection of $\mathbf{a}$ onto the $OY$ axis:
#
# $$
# \text{Proj}_{OY} \mathbf{a} = \frac{\mathbf{a} \cdot \mathbf{j}}{|\mathbf{j}|^2} \mathbf{j} = \frac{\mathbf{a} \cdot \mathbf{j}}{1} \mathbf{j} = (\mathbf{a} \cdot \mathbf{j}) \mathbf{j}
# $$
#
# Recall that $\mathbf{i} = (1, 0)$ and $\mathbf{j} = (0, 1)$ are unit vectors along the $OX$ and $OY$ axes.
#
#
# ## Dividing a Line Segment in a Given Ratio
#
# A line segment is defined by two points in space.
#
# Line segments and vectors are closely related because a line segment connecting two points can be treated as a vector directed from one point to another.
#
# If point \( P \) divides the line segment connecting points $A(x_1, y_1)$ and $B(x_2, y_2)$ in the ratio $m:n$, then the coordinates of point $P$ can be found using the formula:
#
# $$
# P = \left(\frac{n \times x_2 + m \times x_1}{m+n}, \frac{n \times y_2 + m \times y_1}{m+n}\right)
# $$
#
# **Example:**
#
# Given a line segment connecting points $A(1, 2)$ and $B(3, 8)$, find point $P$ that divides the segment in the ratio 2:3.
#
# Coordinates of point $P$:
# $$
# P = \left(\frac{2 \times 3 + 3 \times 1}{2+3}, \frac{2 \times 8 + 3 \times 2}{2+3}\right) = \left(\frac{9}{5}, \frac{22}{5}\right)
# $$

# %%
import matplotlib.pyplot as plt
import math

# Coordinates of points A and B
A = (1, 2)
B = (3, 8)

# Ratio m:n
m, n = 2, 3

# Calculate coordinates of point P that divides the segment in the ratio 2:3
P_x = (n * A[0] + m * B[0]) / (m + n)
P_y = (n * A[1] + m * B[1]) / (m + n)
P = (P_x, P_y)

# Plotting the graph
plt.figure(figsize=(6, 6))

# Plotting line segment AB
plt.plot([A[0], B[0]], [A[1], B[1]], 'k--', label='Line Segment AB')

# Marking points A, B, and P
plt.scatter(*A, color='blue', label='A(1, 2)')
plt.scatter(*B, color='red', label='B(3, 8)')
plt.scatter(*P, color='green', label=f'P({P[0]:.2f}, {P[1]:.2f})')

# Point labels
plt.text(A[0]-0.2, A[1], 'A(1, 2)', fontsize=12, color='blue')
plt.text(B[0]+0.1, B[1], 'B(3, 8)', fontsize=12, color='red')
plt.text(P[0]+0.1, P[1], f'P({P[0]:.2f}, {P[1]:.2f})', fontsize=12, color='green')

# Adding grid and axis labels
plt.grid(True)
plt.xlabel('x')
plt.ylabel('y')
plt.title('Dividing a Line Segment in the Ratio 2:3')
plt.legend()

# Displaying the graph
plt.show()

# %% [raw]
# ---

# %% [markdown]
# ## Student Exercises
#
# - Divide the line segment connecting points $A(-1, 2)$ and $B(3, -2)$ in the ratio $1:3$. Illustrate the result on a graph.
#
# - Project vector $\mathbf{a} = (3, 4)$ onto the $OX$ and $OY$ axes. Illustrate the result on a graph.
#
# - Project vector $\mathbf{a} = (2,3)$ onto vector $\mathbf{b} = (1, 1)$. Illustrate the result on a graph.
#
# - Project vector $\mathbf{b} = (1, 1)$ onto vector $\mathbf{a} = (2, 3)$. Illustrate the result on a graph.

# %% [markdown]
# ### ***Exercise 1***

# %%
import matplotlib.pyplot as plt

# Coordinates of points A and B
point_A = (-1, 2)
point_B = (3, -2)

# Ratio m:n
ratio_m, ratio_n = 1, 3

# Calculate the coordinates of the division point
dividing_point = (
    (ratio_n * point_A[0] + ratio_m * point_B[0]) / (ratio_m + ratio_n),
    (ratio_n * point_A[1] + ratio_m * point_B[1]) / (ratio_m + ratio_n)
)

# Create the plot
plt.figure(figsize=(6, 6))

# Draw the line segment between A and B
plt.plot([point_A[0], point_B[0]], [point_A[1], point_B[1]], linestyle='--', color='black', label='Segment AB')

# Plot points A, B, and the division point
plt.scatter(*point_A, color='blue', label='A(-1, 2)')
plt.scatter(*point_B, color='red', label='B(3, -2)')
plt.scatter(*dividing_point, color='green', label=f'P({dividing_point[0]:.2f}, {dividing_point[1]:.2f})')

# Add axis labels, title, and grid
plt.xlabel('X-axis')
plt.ylabel('Y-axis')
plt.title('Line Segment Division in Ratio 1:3')
plt.legend()
plt.grid(True)

# Show the graph
plt.show()

# %% [markdown]
# ### ***Exercise 2***

# %%
import matplotlib.pyplot as plt

# Vector a
vector_a = (3, 4)

# Projections on axes
projection_X = (3, 0)
projection_Y = (0, 4)

# Create the plot
plt.figure(figsize=(6, 6))

# Plot vector a
plt.arrow(0, 0, vector_a[0], vector_a[1], head_width=0.15, head_length=0.3, color='blue', label='a = (3, 4)')

# Plot projections
plt.arrow(0, 0, projection_X[0], projection_X[1], head_width=0.15, head_length=0.3, color='red', label='Proj_X(a) = (3, 0)')
plt.arrow(0, 0, projection_Y[0], projection_Y[1], head_width=0.15, head_length=0.3, color='green', label='Proj_Y(a) = (0, 4)')

# Set labels, title, and grid
plt.xlabel('X-axis')
plt.ylabel('Y-axis')
plt.title('Vector a and Its Projections on X and Y Axes')
plt.legend()
plt.grid(True)

# Show the graph
plt.show()

# %% [markdown]
# ### ***Exercise 3***

# %%
import matplotlib.pyplot as plt

# Vectors a and b
vector_a = (2, 3)
vector_b = (1, 1)

# Projection of a onto b
projection_b_a = (2.5, 2.5)

# Create the plot
plt.figure(figsize=(6, 6))

# Plot vector a
plt.arrow(0, 0, vector_a[0], vector_a[1], head_width=0.12, head_length=0.25, color='blue', label='a = (2, 3)')

# Plot vector b
plt.arrow(0, 0, vector_b[0], vector_b[1], head_width=0.12, head_length=0.25, color='red', label='b = (1, 1)')

# Plot projection of a onto b
plt.arrow(0, 0, projection_b_a[0], projection_b_a[1], head_width=0.12, head_length=0.25, color='green', label='Proj_b(a) = (2.5, 2.5)')

# Set labels, title, and grid
plt.xlabel('X-axis')
plt.ylabel('Y-axis')
plt.title('Vector a and Its Projection onto Vector b')
plt.legend()
plt.grid(True)

# Show the graph
plt.show()

# %% [markdown]
# ### ***Exercise 4***

# %%
import matplotlib.pyplot as plt

# Vectors a and b
vector_a = (2, 3)
vector_b = (1, 1)

# Projection of b onto a
projection_a_b = (10/13, 15/13)

# Create the plot
plt.figure(figsize=(6, 6))

# Plot vector a
plt.arrow(0, 0, vector_a[0], vector_a[1], head_width=0.12, head_length=0.25, color='blue', label='a = (2, 3)')

# Plot vector b
plt.arrow(0, 0, vector_b[0], vector_b[1], head_width=0.12, head_length=0.25, color='red', label='b = (1, 1)')

# Plot projection of b onto a
plt.arrow(0, 0, projection_a_b[0], projection_a_b[1], head_width=0.12, head_length=0.25, color='green', label='Proj_a(b) = (10/13, 15/13)')

# Set labels, title, and grid
plt.xlabel('X-axis')
plt.ylabel('Y-axis')
plt.title('Projection of Vector b onto Vector a')
plt.legend()
plt.grid(True)

# Show the graph
plt.show()
