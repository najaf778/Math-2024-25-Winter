# %% [markdown]
# <a href="https://colab.research.google.com/github/najaf778/Math-2024-25-Winter/blob/main/Notebooks_EN/02_Analytic_Geometry/07_Planes_in_Space/07_Planes_in_space.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Exercises**
#
# * The plane passes through points $A(1, 2, 3)$, $B(3, 4, 5)$, and $C(2, 1, 4)$. Find the equation of the plane.
# * The plane passes through point $A(1, 2, 3)$ and is parallel to the plane $2x + 3y + 4z = 5$. Find the equation of the plane.
# * The plane passes through point $A(1, 2, 3)$ and is perpendicular to the normal vector $\vec{n} = [2, 3, 4]$. Find the equation of the plane.
# * We have two planes $2x + 3y + 4z = 5$ and $3x + 4y + 2z = 6$. Find the line of intersection of these planes.
# * Write the equation of the plane passing through point $A(1, 2, 3)$ and parallel to vectors $\vec{v_1} = [1, 0, 1]$ and $\vec{v_2} = [0, 1, -1]$.
# * We have the plane $2x + 3y + 4z = 5$. Find an example of a plane parallel and perpendicular to it.
# * We have the plane $2x + 3y + 4z = 5$ and point $A(1, 2, 3)$. Find the distance from point $A$ to this plane.
# * The plane intersects the coordinate axes at points $A(2, 0, 0)$, $B(0, 3, 0)$, and $C(0, 0, 4)$. Find the equation of the plane.
# * Calculate the angle between the plane $x + y + z = 1$ and the plane $x = 0$ (i.e., the $yz$ plane).
# * Find the vector perpendicular to the plane $x + y + z = 1$.

# %% [markdown]
# ## **Exercise 1**
#
# - Find two vectors on the plane:
#
# $
# \vec{AB} = B - A = (3-1, 4-2, 5-3) = (2, 2, 2)
# $
#
# $
# \vec{AC} = C - A = (2-1, 1-2, 4-3) = (1, -1, 1)
# $
#
# - Find the normal vector to the plane:
#
# The normal vector is given by the cross product of $\vec{AB}$ and $\vec{AC}$:
#
# $
# \vec{n} = \vec{AB} \times \vec{AC} = \begin{vmatrix} \hat{i} & \hat{j} & \hat{k} \\ 2 & 2 & 2 \\ 1 & -1 & 1 \end{vmatrix}
# $
#
# $
# \vec{n} = \hat{i} \left( \begin{vmatrix} 2 & 2 \\ -1 & 1 \end{vmatrix} \right) - \hat{j} \left( \begin{vmatrix} 2 & 2 \\ 1 & 1 \end{vmatrix} \right) + \hat{k} \left( \begin{vmatrix} 2 & 2 \\ 1 & -1 \end{vmatrix} \right)
# $
#
# $
# \vec{n} = \hat{i} (2 \times 1 - 2 \times -1) - \hat{j} (2 \times 1 - 2 \times 1) + \hat{k} (2 \times -1 - 2 \times 1)
# $
#
# $
# \vec{n} = \hat{i} (2 + 2) - \hat{j} (2 - 2) + \hat{k} (-2 - 2)
# $
#
# $
# \vec{n} = \hat{i} (4) - \hat{j} (0) + \hat{k} (-4)
# $
#
# $
# \vec{n} = (4, 0, -4)
# $
#
# - Equation of the plane:
#
# Using the point $A(1, 2, 3)$ and the normal vector $(4, 0, -4)$, the equation of the plane is:
#
# $
# 4(x - 1) + 0(y - 2) - 4(z - 3) = 0
# $
#
# Simplifying:
#
# $
# 4x - 4 + 0 - 4z + 12 = 0
# $
#
# $
# 4x - 4z + 8 = 0
# $
#
# $
# x - z + 2 = 0
# $
#
# - The equation of the plane is:
#
# $
# x - z + 2 = 0
# $
#
# ---
#
# ## **Exercise 2**
# Consider the point $A(1, 2, 3)$ and a plane parallel to $2x + 3y + 4z = 5$.
#
# The coefficients of $x$, $y$, and $z$ in the equation, $(2, 3, 4)$, represent the normal vector $\mathbf{n}$ of the plane.
#
# $\mathbf{n} = (2, 3, 4)$
#
# Since the desired plane is parallel to the given plane, its normal vector will remain the same:
# $\mathbf{n} = (2, 3, 4)$
#
# The equation of the required plane can be written as:
# $2x + 3y + 4z = d$
#
# To determine $d$, substitute the coordinates of $A(1, 2, 3)$ into the equation of the plane:
# $2(1) + 3(2) + 4(3) = d$
#
# Simplify:
# $2 + 6 + 12 = d$
# $d = 20$
#
# Thus, the equation of the desired plane is:
# $2x + 3y + 4z = 20$
#
# ---
#
# ## **Exercise 3**
#
# ### 1. Use the point-normal form of the plane equation:
#
# The equation of the plane is:
#
# $
# 2(x - 1) + 3(y - 2) + 4(z - 3) = 0
# $
#
# ### 2. Simplify the equation:
#
# $
# 2x - 2 + 3y - 6 + 4z - 12 = 0
# $
#
# $
# 2x + 3y + 4z - 20 = 0
# $
#
# The equation of the plane is:
#
# $
# 2x + 3y + 4z - 20 = 0
# $
#
# ---
#
# ## **Exercise 4**
#
# ### Given Planes:
# Plane 1: $2x + 3y + 4z = 5$
# Plane 2: $3x + 4y + 2z = 6$
#
# ### Step 1: Normal Vectors
# The normal vectors of the planes are:
# $\vec{n_1} = [2, 3, 4]$, $\vec{n_2} = [3, 4, 2]$
#
# ### Step 2: Direction Vector of Intersection
# The direction vector $\mathbf{d}$ is found using the cross product $\vec{n_1} \times \vec{n_2}$:
# $$
# \mathbf{d} = \begin{vmatrix}
# \mathbf{i} & \mathbf{j} & \mathbf{k} \\
# 2 & 3 & 4 \\
# 3 & 4 & 2
# \end{vmatrix}
# $$
#
# Expand the determinant:
# $$
# \mathbf{d} = \mathbf{i} \begin{vmatrix} 3 & 4 \\ 4 & 2 \end{vmatrix} - \mathbf{j} \begin{vmatrix} 2 & 4 \\ 3 & 2 \end{vmatrix} + \mathbf{k} \begin{vmatrix} 2 & 3 \\ 3 & 4 \end{vmatrix}
# $$
#
# Calculate each minor:
# $$
# \mathbf{d} = \mathbf{i}(-10) - \mathbf{j}(-8) + \mathbf{k}(-1)
# $$
#
# Simplify:
# $$
# \mathbf{d} = [-10, 8, -1]
# $$
#
# ### Step 3: Solve for a Point on the Line
# To find a specific point on the line of intersection, set $z = 0$.
#
# - **Plane 1:**
#   $2x + 3y + 4(0) = 5 \quad \Rightarrow \quad 2x + 3y = 5$
#
# - **Plane 2:**
#   $3x + 4y + 2(0) = 6 \quad \Rightarrow \quad 3x + 4y = 6$
#
# ### Step 4: Eliminate $x$
# Multiply Plane 1 by $3$ and Plane 2 by $2$:
# $$
# \begin{cases}
# 6x + 9y = 15 \\
# 6x + 8y = 12
# \end{cases}
# $$
#
# Subtract the equations:
# $$
# (6x + 9y) - (6x + 8y) = 15 - 12
# $$
# $$
# y = 3
# $$
#
# ### Step 5: Solve for $x$
# Substitute $y = 3$ into $2x + 3y = 5$:
# $$
# 2x + 3(3) = 5
# $$
# $$
# 2x + 9 = 5
# $$
# $$
# 2x = -4 \quad \Rightarrow \quad x = -2
# $$
#
# ### Step 6: Parametric Equations
# Using the direction vector $\mathbf{d} = [-10, 8, -1]$:
# $$
# x = -2 - 10t \\
# y = 3 + 8t \\
# z = -t
# $$
#
# ### Final Answer:
# The line of intersection is:
# $$
# \boxed{
# \begin{aligned}
# x &= -2 - 10t \\
# y &= 3 + 8t \\
# z &= -t
# \end{aligned}
# }
# $$
# where $t$ is a parameter.
#
# ---
#
# ## **Exercise 5**
# $A(1,2,3)$ parallel to $\vec{v_1} = [1,0,1]$ and $\vec{v_2} = [0,1,-1]$
#
# 1) $\vec{n} = \vec{v_1} \times \vec{v_2} = \left| \begin{matrix} \hat{i} & \hat{j} & \hat{k} \\ 1 & 0 & 1 \\ 0 & 1 & -1 \end{matrix} \right| $
#
# $ \vec{n} = \hat{i}( \begin{vmatrix} 0 & 1 \\ 1 & -1 \end{vmatrix}) - \hat{j} ( \begin{vmatrix} 1 & 1 \\ 0 & -1 \end{vmatrix}) + \hat{k} ( \begin{vmatrix} 1 & 0 \\ 0 & 1 \end{vmatrix})$
#
# $ \vec{n} = -2\hat{i} + \hat{j} + \hat{k} $
#
# The general equation of a plane is:
# $a(x - x_0) + b(y - y_0) + c(z - z_0) = 0$
#
# Substituting the point $A(1, 2, 3)$ and the normal vector $\langle -2, 1, 1 \rangle$
#
# $-2(x - 1) + 1(y - 2) + 1(z - 3) = 0$
#
# $-2x + 2 + y - 2 + z - 3 = 0$
#
# $-2x + y + z - 3 = 0$
#
# $\boxed{-2x + y + z = 3}$
#
# ---
#
# ## **Exercise 6**
# Plane $2x + 3y + 4z = 5$
#
# 1) Parallel Plane:
#
# $\vec{n}= [2, 3, 4]$
#
# A parallel plane will have the same normal vector but a different constant on the right-hand side.
#
# ${2x + 3y + 4z = d} $
#
# For example, the equation of a parallel plane could be:
#
# $ 2x + 3y + 4z = 10 $
#
# 2)Perpendicular Plane:
#
# $\vec{n_g}=\langle 2, 3, 4 \rangle$
#
# $\mathbf{plane_p}= \vec{n_{px}}x+ \vec{n_{py}}y+ \vec{n_{pz}}z$
#
# For example, let's choose a vector $\langle 3, -2, 0 \rangle$ which is perpendicular to $\langle 2, 3, 4 \rangle$ (since their dot product is zero: $2(3) + 3(-2) + 4(0) = 0$).
#
# $ 3x - 2y = 7 $
#
# ---
#
# ## **Exercise 7**
# Plane $2x + 3y + 4z = 5$ and point $A(1, 2, 3)$
#
# The formula for the distance $d$ from a point $(x_1, y_1, z_1)$ to a plane $Ax + By + Cz + D = 0$ is:
#
# $$d = \frac{|Ax_1 + By_1 + Cz_1 + D|}{\sqrt{A^2 + B^2 + C^2}}$$
#
# 1)$2x + 3y + 4z - 5 = 0$
#
# Here, $A = 2$, $B = 3$, $C = 4$, and $D = -5$. The point $A(1, 2, 3)$ has coordinates $(x_1, y_1, z_1) = (1, 2, 3)$.
#
# $d = \frac{|2(1) + 3(2) + 4(3) - 5|}{\sqrt{2^2 + 3^2 + 4^2}}$
#
# $d = \frac{|2 + 6 + 12 - 5|}{\sqrt{4 + 9 + 16}} = \frac{|15|}{\sqrt{29}} = \frac{15}{\sqrt{29}}$
#
# ---
#
# ## **Exercise 8**
# The plane intersects the coordinate axes at points $A(2, 0, 0)$, $B(0, 3, 0)$, and $C(0, 0, 4)$
#
# General formula of the plane equation:
#
# $$Ax + By + Cz = D$$
#
# 1)For point $A(2, 0, 0)$:
#
# $A(2) + B(0) + C(0) = D \implies 2A = D$
#
# 2)For point $B(0, 3, 0)$:
#
# $A(0) + B(3) + C(0) = D \implies 3B = D$
#
# 3)For point $C(0, 0, 4)$:
#
# $A(0) + B(0) + C(4) = D \implies 4C = D$
#
# Now, we have the system of equations:
#
# $\begin{cases}2A = D\\ 3B = D\\ 4C = D\end{cases}$
#
# Thus, $A : B : C = 1 : \frac{1}{2} : \frac{1}{4}$
#
# This ratio tells us that for any plane equation, the coefficients $A$, $B$, and $C$ should be in the ratio $1 : \frac{1}{2} : \frac{1}{4}$
#
# The equation of the plane is:
#
# $x + \frac{y}{2} + \frac{z}{4} = 1$
#
# ---
#
# ## **Exercise 9**
# Plane $x + y + z = 1$ and the plane $x = 0$ (the $yz$ plane)
#
# 1)$\vec{n_1}=x + y + z = \langle 1, 1, 1 \rangle$.
#
# $\vec{n_2}=x= \langle 1, 0, 0 \rangle$.
#
# The formula to calculate the angle $\theta$ between two vectors $\vec{n_1}$ and $\vec{n_2}$ is:
#
# $$ \cos \theta = \frac{\vec{n_1} \cdot \vec{n_2}}{\|\vec{n_1}\| \|\vec{n_2}\|} $$
#
# Where:
# - $\vec{n_1} \cdot \vec{n_2}$ is the dot product of the vectors.
# - $\|\vec{n_1}\|$ and $\|\vec{n_2}\|$ are the magnitudes (norms) of the vectors.
#
# 2)$ \vec{n_1} \cdot \vec{n_2} = 1 \times 1 + 1 \times 0 + 1 \times 0 = 1 $
#
# The magnitudes of $\vec{n_1}$ and $\vec{n_2}$ are:
#
# 3)$ \|\vec{n_1}\| = \sqrt{1^2 + 1^2 + 1^2} = \sqrt{3} $
#
# $ \|\vec{n_2}\| = \sqrt{1^2 + 0^2 + 0^2} = 1 $
#
# 4)$ \cos \theta = \frac{1}{\sqrt{3} \times 1} = \frac{1}{\sqrt{3}} $
#
# 5)$ \theta = \cos^{-1}\left(\frac{1}{\sqrt{3}}\right) $
#
# ---
#
# ## **Exercise 10**
# Plane $x + y + z = 1$
#
# The general form of a plane equation is $Ax + By + Cz = D$, where the vector $\vec{n} = \langle A, B, C \rangle$ is the normal vector to the plane.
#
# In the equation of the plane $x + y + z = 1$, we can see that $A = 1$, $B = 1$, and $C = 1$. Therefore, the normal vector to the plane is:
#
# $ \vec{n} = \langle 1, 1, 1 \rangle $
#
# The vector perpendicular to the plane $x + y + z = 1$ is:
#
# $ \vec{n} = \langle 1, 1, 1 \rangle $
